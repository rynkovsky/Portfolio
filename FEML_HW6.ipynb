# %%
from sklearn.datasets import load_boston
import pandas as pd
data = pd.read_csv(load_boston()['filename'], skiprows=1)

# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
exclude_columns = ['MEDV']
X = data.drop(columns=exclude_columns)
y = data['MEDV']

# %%
model_LR = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)  
model_LR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model_LR.score(X_test, y_test)
# Out:
# 0.6897429986875577

# %%
model_DTR = DecisionTreeRegressor()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)  
model_DTR.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
model_DTR.score(X_test, y_test)
# Out:
# 0.5621352704626597

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(model_DTR, feature_names=data.columns, filled=True)

# %%
plt.barh(np.arange(len(model_DTR.feature_importances_)), model_DTR.feature_importances_)
plt.yticks(np.arange(len(X.columns)),X.columns)
''
# Out:
# ''
